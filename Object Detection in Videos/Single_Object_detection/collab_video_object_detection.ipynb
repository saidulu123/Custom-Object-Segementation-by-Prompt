# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.6/779.6 kB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 61.2 MB/s eta 0:00:00

# %%
# !yolo detect predict model=yolov8n.pt source="/content/teaser.mov"
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 308MB/s]
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (frame 1/320) /content/teaser.mov: 384x640 1 person, 72.5ms
# video 1/1 (frame 2/320) /content/teaser.mov: 384x640 1 person, 11.3ms
# video 1/1 (frame 3/320) /content/teaser.mov: 384x640 1 person, 20.5ms
# video 1/1 (frame 4/320) /content/teaser.mov: 384x640 1 person, 17.2ms
# video 1/1 (frame 5/320) /content/teaser.mov: 384x640 1 person, 1 refrigerator, 17.5ms
# video 1/1 (frame 6/320) /content/teaser.mov: 384x640 1 person, 1 refrigerator, 11.9ms
# video 1/1 (frame 7/320) /content/teaser.mov: 384x640 1 person, 1 refrigerator, 14.5ms
# video 1/1 (frame 8/320) /content/teaser.mov: 384x640 1 person, 1 refrigerator, 13.0ms
# video 1/1 (frame 9/320) /content/teaser.mov: 384x640 1 person, 1 refrigerator, 9.6ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict/teaser.avi"} -vcodec libx264 {"object_detection_in_video.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
