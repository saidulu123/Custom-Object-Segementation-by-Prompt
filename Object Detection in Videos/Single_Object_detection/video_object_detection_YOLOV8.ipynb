# %%
# !pip install ultralytics -q
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !yolo detect predict model=yolov8n.pt source="E:\\My projects\\Object Detection in Videos\\input_videos\\foreground_video.mp4"
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.11.7 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (frame 1/481) E:\My projects\Object Detection in Videos\input_videos\foreground_video.mp4: 288x640 1 person, 1 bench, 72.6ms
# video 1/1 (frame 2/481) E:\My projects\Object Detection in Videos\input_videos\foreground_video.mp4: 288x640 2 persons, 4.0ms
# video 1/1 (frame 3/481) E:\My projects\Object Detection in Videos\input_videos\foreground_video.mp4: 288x640 2 persons, 4.0ms
# video 1/1 (frame 4/481) E:\My projects\Object Detection in Videos\input_videos\foreground_video.mp4: 288x640 2 persons, 3.0ms
# video 1/1 (frame 5/481) E:\My projects\Object Detection in Videos\input_videos\foreground_video.mp4: 288x640 2 persons, 4.5ms
# video 1/1 (frame 6/481) E:\My projects\Object Detection in Videos\input_videos\foreground_video.mp4: 288x640 2 persons, 4.0ms
# ...
